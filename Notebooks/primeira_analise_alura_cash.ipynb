# %% [markdown]
# <a href="https://colab.research.google.com/github/karolbgoes/Challenge_Alura_Cash/blob/main/Notebooks/primeira_analise_alura_cash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
base = 'https://raw.githubusercontent.com/tarik-pomim/challenge_dados_082022/main/dados.csv'

# %%
dataset = pd.read_csv (base)

# %%
## Análises Preliminares

# %%
dataset.sample (100)
# Out:
#            person_id        loan_id          cb_id    person_id.1  person_age  \
# 4217   eGR7C5uA-KEkz  XbTmU6Lj-NvY3  Jkj359OL-oKDt  eGR7C5uA-KEkz        23.0
# 34109  t6jRBzNT-E93E  O7siqvJJ-PIiy  L4ZE98ya-Gz6g  t6jRBzNT-E93E        22.0
# 4278   5OuuBl9g-LAGr  XDwkipP0-QIJb  CK79IdGO-XNOD  5OuuBl9g-LAGr        24.0
# 7358   dHZnEGRc-SNpk  rD3oI10A-Bt2j  ubHDSLtu-91Go  dHZnEGRc-SNpk        28.0
# 31239  pTeCNkMN-NhfG  shrUHQJa-SZHd  uWsTxaTU-1M3H  pTeCNkMN-NhfG        23.0
# ...              ...            ...            ...            ...         ...
# 1732   zNNB28ty-Ab1Y  ZjisXyD4-bwRD  1KHpytBF-Zs49  zNNB28ty-Ab1Y        21.0
# 17789  ZwxvYG6X-yTZq  tujKkoao-Cf4t  tbyKmMmf-YcYw  ZwxvYG6X-yTZq        27.0
# 5615   DIWC2G46-8vbx  OuTXoAxJ-h7ki  ty5yUjlm-izCJ  DIWC2G46-8vbx        24.0
# 14362  HRXbgMBe-dW6t  Edi2tPGT-bMAf  q9A4l7ru-Qqjn  HRXbgMBe-dW6t        23.0
# 26358  jcqEz21X-Ptsh  homcQcOD-D3At  FDRTnRLm-dEeO  jcqEz21X-Ptsh        22.0
#
# ...

# %%
dataset.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34501 entries, 0 to 34500
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_id                   34485 non-null  object
#  1   loan_id                     34501 non-null  object
#  2   cb_id                       34501 non-null  object
#  3   person_id.1                 34485 non-null  object
#  4   person_age                  34177 non-null  float64
#  5   person_income               34162 non-null  float64
#  6   person_home_ownership       34170 non-null  object
#  7   person_emp_length           33247 non-null  float64
#  8   loan_id.1                   34501 non-null  object
#  9   loan_intent                 34186 non-null  object
#  10  loan_grade                  34188 non-null  object
#  11  loan_amnt                   34170 non-null  float64
#  12  loan_int_rate               30871 non-null  float64
# ...

# %%
#Traduzindo as colunas para português

# %%
colunas_portugues = {
    'person_id' : 'id_solicitante',
    'loan_id' : 'id_emprestimo',
    'cb_id' : 'id_historico',
    'person_age' : 'idade',
    'person_income' : 'salario_anual',
    'person_home_ownership' : 'situacao_imovel',
    'person_emp_length' : 'anos_empregado',
    'loan_intent' : 'motivo_emprestimo',
    'loan_grade' : 'pontuacao_emprestimo',
    'loan_amnt' : 'total_a_emprestar',
    'loan_int_rate' : 'juros',
    'loan_status' : 'possibilidade_inadimplencia',
    'loan_percent_income' : 'percentual_emprestimo_renda',
    'cb_person_default_on_file' : 'ja_foi_inadimplente',
    'cb_person_cred_hist_length' : 'anos_de_credito'
}

dataset.rename(mapper = colunas_portugues, axis = 1, inplace = True)

# %%
dataset.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34501 entries, 0 to 34500
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_solicitante               34485 non-null  object
#  1   id_emprestimo                34501 non-null  object
#  2   id_historico                 34501 non-null  object
#  3   person_id.1                  34485 non-null  object
#  4   idade                        34177 non-null  float64
#  5   salario_anual                34162 non-null  float64
#  6   situacao_imovel              34170 non-null  object
#  7   anos_empregado               33247 non-null  float64
#  8   loan_id.1                    34501 non-null  object
#  9   motivo_emprestimo            34186 non-null  object
#  10  pontuacao_emprestimo         34188 non-null  object
#  11  total_a_emprestar            34170 non-null  float64
# ...
